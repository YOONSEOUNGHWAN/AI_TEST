# %% [markdown]
# <a href="https://colab.research.google.com/github/YOONSEOUNGHWAN/AI_TEST/blob/main/%EC%B9%B4%EC%B9%B4%EC%98%A4%ED%86%A1%EC%A0%84%EC%B2%98%EB%A6%ACipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import os
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def katalk_msg_parse(file_path):
  my_katalk_data = list()
  katalk_msg_pattern = "[0-9]{4}[년.] [0-9]{1,2}[일.] [0-9]{1,2}[오\S.] [0-9]{1,2}:[0-9]{1,2},.*:" #카카오톡 메시지 패턴
  date_info = "[0-9]{4}년 [0-9]{1,2}월 [0-9]{1,2}일 \S요일" #날짜 바뀌는 패턴
  in_out_info = "[0-9]{4}[년.] [0-9]{1,2}[월.] [0-9]{1,2}[일.] 오\S [0-9]{1,2}:[0-9]{1,2}:.*" #나갔다는 알림 무시
  money_text = "[0-9]{4}[년.] [0-9]{1,2}[일.] [0-9]{1,2}[오\S.] [0-9]{1,2}:[0-9]{1,2},.*:.[0-9]{1,3},.*원"#카카오페이 돈거래
  audio_visual_text = "^동영상$|^사진$|^사진 [0-9]{1,2}장$|^이모티콘$^봉투가 도착했어요.$" #사진이나 동영상 메세지, 이모티콘은 추가 x

  for line in open(file_path):
    if re.match(date_info, line) or re.match(in_out_info, line) or re.match(money_text, line):
      continue
    elif line == '\n':
      continue
    elif re.match(katalk_msg_pattern, line):
      line = line.split(",") #,기준 2020. 1. 23. 11:57, 윤승환 : 너 친구약속 만나?
      date_time = line[0]
      user_text = line[1].split(" : ", maxsplit=1)
      user_name = user_text[0].strip()
      text = user_text[1].strip()
      if re.match(audio_visual_text, text): #사진 짤
        continue
      elif my_katalk_data and my_katalk_data[-1]['user_name'] == user_name: #동일 인물의 발화에 대해서..
        my_katalk_data[-1]['text'] += " "+ text
      else:
        my_katalk_data.append({"date_time": date_time,
                              "user_name": user_name,
                              "text": text})
    else:
      if len(my_katalk_data) > 0:
        my_katalk_data[-1]['text'] += "\n"+line.strip() #의도적으로 문장을 나눈 경우
    
  my_katalk_df = pd.DataFrame(my_katalk_data)

  return my_katalk_df

# %%
f_path = '/content/drive/MyDrive/Colab Notebooks'
f_name = 'katalk_data.txt'

df = katalk_msg_parse(os.path.join(f_path, f_name))
df[100:150]
# Out:
#               date_time user_name  \
# 100  2020. 1. 24. 12:08       윤승환
# 101  2020. 1. 24. 12:08     17김승주
# 102  2020. 1. 24. 12:08       윤승환
# 103  2020. 1. 24. 12:09     17김승주
# 104  2020. 1. 24. 12:09       윤승환
# 105  2020. 1. 24. 12:10     17김승주
# 106  2020. 1. 24. 12:10       윤승환
# 107  2020. 1. 24. 12:10     17김승주
# 108  2020. 1. 24. 12:10       윤승환
# 109  2020. 1. 24. 12:11     17김승주
# 110  2020. 1. 24. 12:11       윤승환
# 111  2020. 1. 24. 12:11     17김승주
# 112  2020. 1. 24. 12:12       윤승환
# 113  2020. 1. 24. 12:12     17김승주
# 114  2020. 1. 24. 12:12       윤승환
# 116                                  아 이거 어떻게 짜냐고 ㅠㅠㅠㅠ
# 117                                         너 세사봉끝냈어?0
# 118                                         나 그거 농활가랴구
# 119                             읭 그게 가능해? 농활 학기중에갈수이써?
# 120                          농활한번만가면 세사봉끝이라던대 몰라그건ㅋㅋㅋㅋ
# 121         ㅇㅅㅇ 계획이 그닥 철저하지않구나 기다려바 내가 짜볼게 너21학점들을수있지?
# 122                                                 어때
# 123                                             내가 짜볼게
# 124             아니 승주야 이거 다 필수야 ㅋㅋㅋㅋㅋ 이미 20학점임걸 아닌가..?
# 125                                   세계사 erp 세사봉도 필수야
# 126                                                아낮네
# 127                                공수 신청안해도돼 나도 신청안했었어
# 128                                            공수하라던대?
# 129                                            너 전과한다며
# 130                                                 응응
# 131                                          거기서 필요앖으면
# 132                                                  아
# 133                                        미리 할 필요가 없지
# 134                                                 아아
# 135                                   실패하고 나중에 신청해도되는데
# 136                                             그러면 맞아
# 137                                                 일단
# 138                                           전과실패하면어케
# 139   캄공과 환에공 공통 필수인걸로 다 채워넣고 그래서 세사봉 세계사 erp가 일순의라는거야
# 140                                         이알피는 공통필수다
# 141                                               새계사도
# 142                            승주 나 21학점 기준이 3.5야 전학기?
# 143                                                 응응
# 144                             나 18학점... ㅋㅋㅋㅋㅋㅋ 21못채워
# 145                             기다려바 내가 빅피쳐로 다 세워주께^0^
# 146                             여기서 일본어 에프거든ㅋㅋ 고프 시플이구
# 147                                    ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아 맞아
# 148                                     이게 발목을잡네 ㅋ 그리구
# 149                                                 승환

# %%
df['msg_len'] = df['text'].str.len()
df['msg_word_count'] = df['text'].str.split().str.len()
df
# Out:
#                 date_time user_name  \
# 0      2020. 1. 22. 23:59       윤승환
# 1      2020. 1. 23. 03:43     17김승주
# 2      2020. 1. 23. 04:02       윤승환
# 3      2020. 1. 23. 04:06     17김승주
# 4      2020. 1. 23. 11:57       윤승환
# ...                   ...       ...
# 7375  2020. 10. 21. 01:18     17김승주
# 7376  2020. 10. 21. 01:18       윤승환
# 7377  2020. 10. 21. 01:18     17김승주
# 7378  2020. 10. 21. 01:18       윤승환
# 7379  2020. 10. 21. 01:18     17김승주
#
#                                            text  msg_len  msg_word_count
# 0                                    봉투가 도착했어요.       10               2
# 1                                 우우 어우 너무 머리아파       13               4
# 2                                           안자?        3               1
# 3                   자려고 눕긴했엉 자야지.. 승환 속 괜찮아?ㅋㅋㅋ       27               6
# 4                           ㅋㅋㅋㅋㅋㅋ 와 너 친구약속 만나?       19               5
# ...                                         ...      ...             ...
# 7375                                        맞아?        3               1
# 7376                                    응음자아 맞아        7               2
# 7377                                 그러면 부탁한다..       10               2
# 7378                     ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 주소랑 링크걸어       22               3
# 7379  오 진짜 땡큐 이렇게 빨리쓰게될쥴몰랐엌ㅋㅋㅋㅋ 이거 꼼마꼼마 마스크라고쓰면       41               8
#
# [7380 rows x 5 columns]

# %%
df.to_pickle(os.path.join(f_path, "katalk_data.pkl"))
